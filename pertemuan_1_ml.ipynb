# %% [markdown]
# <a href="https://colab.research.google.com/github/Raffi38321/pt-1-ml/blob/main/pertemuan_1_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
print("pandas: ",pd.__version__)
print("numpy: ",np.__version__)
print("scikit-learn: ",sklearn.__version__)
# Out:
# pandas:  2.2.3
# numpy:  2.1.3
# scikit-learn:  1.6.1

# %%
from getpass import getpass
username = input('Username GitHub: ')
token = getpass('Personal Access Token: ')
# Out:
# Username GitHub: raffi38321
# Personal Access Token: ··········

# %%
repo = 'pt-1-ml'
# !git clone https://{username}:{token}@github.com/{username}/{repo}.git
# Menyalin notebook hasil kerja ke folder repo (sesuaikan path)
# !cp '/content/pertemuan 1 ml.ipynb' {repo}/
# Mengatur identitas, lalu commit & push
# !cd {repo} && git config user.email 'email@anda.com'
# !cd {repo} && git config user.name '{username}'
# !cd {repo} && git add . && git commit -m 'Selesai praktikum EDA'
# !cd {repo} && git push origin main
# Out:
# fatal: destination path 'pt-1-ml' already exists and is not an empty directory.
# cp: cannot stat '/content/pertemuan 1 ml.ipynb': No such file or directory
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/raffi38321/pt-1-ml.git'
